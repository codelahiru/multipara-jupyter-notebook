# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('train.csv')
#, encoding="utf-8"

# %%
# Normalize the pixel values
data = np.array(data)
data[:, 1:] = data[:, 1:] / 255.0

# %%
# Shuffle the data
np.random.shuffle(data)

# %%
# Split the data into training and development sets
data_dev = data[:1000].T
Y_dev = data_dev[0]
X_dev = data_dev[1:]

data_train = data[1000:].T
Y_train = data_train[0]
X_train = data_train[1:]

# %%
# Initializing parameters

def init_params():
    W1 = np.random.rand(10, 784)
    b1 = np.random.rand(10, 1)
    W2 = np.random.rand(10, 10)
    b2 = np.random.rand(10, 1)
    return W1, b1, W2, b2

# %%
# forward propagation

def ReLU(Z):
    return np.maximum(0, Z)

# def softmax(Z):
#     return np.exp(Z)/np.sum(np.exp(Z))

def stable_softmax(Z):
    Z -= np.max(Z)  # Subtract the maximum value for stability
    exp_Z = np.exp(Z)
    return exp_Z / np.sum(exp_Z)

def forward_prop(W1, b1, W2, b2, X):
    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = stable_softmax(Z2)
    return Z1, A1, Z2, A2

# %%
# backward propagation

def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    one_hot_Y = one_hot_Y.T
    return one_hot_Y

def deriv_ReLU(Z):
    return Z > 0

def back_prop(Z1, A1, Z2, A2, W2, X, Y):
    m = Y.size
    one_hot_Y = one_hot(Y)
    dZ2 = A2 - one_hot_Y
    dW2 = 1/m * dZ2.dot(A1.T)
    db2 = 1/m * np.sum(dZ2, axis=1, keepdims=True)
    dZ1 = W2.T.dot(dZ2) * deriv_ReLU(Z1)
    dW1 = 1/m * dZ1.dot(X.T)
    db1 = 1/m * np.sum(dZ1, axis=1, keepdims=True)
    return dW1, db1, dW2, db2

# %%
def update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha):
    W1 = W1 - alpha * dW1
    b1 = b1 - alpha * db1
    W2 = W2 - alpha * dW2
    b2 = b2 - alpha * db2
    return W1, b1, W2, b2

# %%
def get_predictions(A2):
    return np.argmax(A2, 0)

def get_accuracy(predictions, Y):
    return np.sum(predictions == Y) / Y.size

# %%
def gradient_descent(X, Y, iterations, alpha):
    W1, b1, W2, b2 = init_params()
    for i in range(iterations):
        Z1, A1, Z2, A2 = forward_prop(W1, b1, W2, b2, X)
        dW1, db1, dW2, db2 = back_prop(Z1, A1, Z2, A2, W2, X, Y)
        W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
        if (i % 10 == 0):
            predictions = get_predictions(A2)
            accuracy = get_accuracy(predictions, Y)
            print(f'Iteration: {i}, Accuracy: {accuracy:.4f}')

    return W1, b1, W2, b2

# Increase the number of iterations and adjust the learning rate as needed
W1, b1, W2, b2 = gradient_descent(X_train, Y_train, 10000, 0.01)
# Out:
# Iteration: 0, Accuracy: 0.1116
# Iteration: 10, Accuracy: 0.0924
# Iteration: 20, Accuracy: 0.0992
# Iteration: 30, Accuracy: 0.0987
# Iteration: 40, Accuracy: 0.0984
# Iteration: 50, Accuracy: 0.0981
# Iteration: 60, Accuracy: 0.0978
# Iteration: 70, Accuracy: 0.0977
# Iteration: 80, Accuracy: 0.0974
# Iteration: 90, Accuracy: 0.0973
# Iteration: 100, Accuracy: 0.0974
# Iteration: 110, Accuracy: 0.0973
# Iteration: 120, Accuracy: 0.0975
# Iteration: 130, Accuracy: 0.0976
# Iteration: 140, Accuracy: 0.0977
# Iteration: 150, Accuracy: 0.0977
# Iteration: 160, Accuracy: 0.0979
# Iteration: 170, Accuracy: 0.0981
# Iteration: 180, Accuracy: 0.0981
# Iteration: 190, Accuracy: 0.0980
# Iteration: 200, Accuracy: 0.0980
# Iteration: 210, Accuracy: 0.0981
# Iteration: 220, Accuracy: 0.0983
# Iteration: 230, Accuracy: 0.0983
# Iteration: 240, Accuracy: 0.0985
# Iteration: 250, Accuracy: 0.0984
# Iteration: 260, Accuracy: 0.0985
# Iteration: 270, Accuracy: 0.0986
# Iteration: 280, Accuracy: 0.0986
# Iteration: 290, Accuracy: 0.0987
# Iteration: 300, Accuracy: 0.0986
# Iteration: 310, Accuracy: 0.0985
# Iteration: 320, Accuracy: 0.0985
# Iteration: 330, Accuracy: 0.0986
# Iteration: 340, Accuracy: 0.0986
# Iteration: 350, Accuracy: 0.0987
# Iteration: 360, Accuracy: 0.0987
# Iteration: 370, Accuracy: 0.0987
# Iteration: 380, Accuracy: 0.0987
# Iteration: 390, Accuracy: 0.0987
# Iteration: 400, Accuracy: 0.0987
# Iteration: 410, Accuracy: 0.0987
# Iteration: 420, Accuracy: 0.0987
# Iteration: 430, Accuracy: 0.0987
# Iteration: 440, Accuracy: 0.0987
# Iteration: 450, Accuracy: 0.0987
# Iteration: 460, Accuracy: 0.0987
# Iteration: 470, Accuracy: 0.0987
# Iteration: 480, Accuracy: 0.0987
# Iteration: 490, Accuracy: 0.0987
# Iteration: 500, Accuracy: 0.0987
# Iteration: 510, Accuracy: 0.0987
# Iteration: 520, Accuracy: 0.0987
# Iteration: 530, Accuracy: 0.0987
# Iteration: 540, Accuracy: 0.0987
# Iteration: 550, Accuracy: 0.0987
# Iteration: 560, Accuracy: 0.0987
# Iteration: 570, Accuracy: 0.0987
# Iteration: 580, Accuracy: 0.0987
# Iteration: 590, Accuracy: 0.0987
# Iteration: 600, Accuracy: 0.0987
# Iteration: 610, Accuracy: 0.0987
# Iteration: 620, Accuracy: 0.0987
# Iteration: 630, Accuracy: 0.0987
# Iteration: 640, Accuracy: 0.0987
# Iteration: 650, Accuracy: 0.0987
# Iteration: 660, Accuracy: 0.0987
# Iteration: 670, Accuracy: 0.0987
# Iteration: 680, Accuracy: 0.0987
# Iteration: 690, Accuracy: 0.0987
# Iteration: 700, Accuracy: 0.0987
# Iteration: 710, Accuracy: 0.0987
# Iteration: 720, Accuracy: 0.0987
# Iteration: 730, Accuracy: 0.0987
# Iteration: 740, Accuracy: 0.0987
# Iteration: 750, Accuracy: 0.0987
# Iteration: 760, Accuracy: 0.0987
# Iteration: 770, Accuracy: 0.0987
# Iteration: 780, Accuracy: 0.0987
# Iteration: 790, Accuracy: 0.0987
# Iteration: 800, Accuracy: 0.0987
# Iteration: 810, Accuracy: 0.0987
# Iteration: 820, Accuracy: 0.0987
# Iteration: 830, Accuracy: 0.0987
# Iteration: 840, Accuracy: 0.0987
# Iteration: 850, Accuracy: 0.0987
# Iteration: 860, Accuracy: 0.0987
# Iteration: 870, Accuracy: 0.0987
# Iteration: 880, Accuracy: 0.0987
# Iteration: 890, Accuracy: 0.0987
# Iteration: 900, Accuracy: 0.0987
# Iteration: 910, Accuracy: 0.0987
# Iteration: 920, Accuracy: 0.0987
# Iteration: 930, Accuracy: 0.0987
# Iteration: 940, Accuracy: 0.0987
# Iteration: 950, Accuracy: 0.0987
# Iteration: 960, Accuracy: 0.0987
# Iteration: 970, Accuracy: 0.0987
# Iteration: 980, Accuracy: 0.0987
# Iteration: 990, Accuracy: 0.0987
# Iteration: 1000, Accuracy: 0.0987
# Iteration: 1010, Accuracy: 0.0987
# Iteration: 1020, Accuracy: 0.0987
# Iteration: 1030, Accuracy: 0.0987
# Iteration: 1040, Accuracy: 0.0987
# Iteration: 1050, Accuracy: 0.0987
# Iteration: 1060, Accuracy: 0.0987
# Iteration: 1070, Accuracy: 0.0987
# Iteration: 1080, Accuracy: 0.0987
# Iteration: 1090, Accuracy: 0.0987
# Iteration: 1100, Accuracy: 0.0987
# Iteration: 1110, Accuracy: 0.0987
# Iteration: 1120, Accuracy: 0.0987
# Iteration: 1130, Accuracy: 0.0987
# Iteration: 1140, Accuracy: 0.0987
# Iteration: 1150, Accuracy: 0.0987
# Iteration: 1160, Accuracy: 0.0987
# Iteration: 1170, Accuracy: 0.0987
# Iteration: 1180, Accuracy: 0.0987
# Iteration: 1190, Accuracy: 0.0987
# Iteration: 1200, Accuracy: 0.0987
# Iteration: 1210, Accuracy: 0.0987
# Iteration: 1220, Accuracy: 0.0987
# Iteration: 1230, Accuracy: 0.0987
# Iteration: 1240, Accuracy: 0.0987
# Iteration: 1250, Accuracy: 0.0987
# Iteration: 1260, Accuracy: 0.0987
# Iteration: 1270, Accuracy: 0.0987
# Iteration: 1280, Accuracy: 0.0987
# Iteration: 1290, Accuracy: 0.0987
# Iteration: 1300, Accuracy: 0.0987
# Iteration: 1310, Accuracy: 0.0987
# Iteration: 1320, Accuracy: 0.0987
# Iteration: 1330, Accuracy: 0.0987
# Iteration: 1340, Accuracy: 0.0987
# Iteration: 1350, Accuracy: 0.0987
# Iteration: 1360, Accuracy: 0.0987
# Iteration: 1370, Accuracy: 0.0987
# Iteration: 1380, Accuracy: 0.0987
# Iteration: 1390, Accuracy: 0.0987
# Iteration: 1400, Accuracy: 0.0987
# Iteration: 1410, Accuracy: 0.0987
# Iteration: 1420, Accuracy: 0.0987
# Iteration: 1430, Accuracy: 0.0987
# Iteration: 1440, Accuracy: 0.0987
# Iteration: 1450, Accuracy: 0.0987
# Iteration: 1460, Accuracy: 0.0987
# Iteration: 1470, Accuracy: 0.0987
# Iteration: 1480, Accuracy: 0.0987
# Iteration: 1490, Accuracy: 0.0987
# Iteration: 1500, Accuracy: 0.0987
# Iteration: 1510, Accuracy: 0.0987
# Iteration: 1520, Accuracy: 0.0987
# Iteration: 1530, Accuracy: 0.0987
# Iteration: 1540, Accuracy: 0.0987
# Iteration: 1550, Accuracy: 0.0987
# Iteration: 1560, Accuracy: 0.0987
# Iteration: 1570, Accuracy: 0.0987
# Iteration: 1580, Accuracy: 0.0987
# Iteration: 1590, Accuracy: 0.0987
# Iteration: 1600, Accuracy: 0.0987
# Iteration: 1610, Accuracy: 0.0987
# Iteration: 1620, Accuracy: 0.0987
# Iteration: 1630, Accuracy: 0.0987
# Iteration: 1640, Accuracy: 0.0987
# Iteration: 1650, Accuracy: 0.0987
# Iteration: 1660, Accuracy: 0.0987
# Iteration: 1670, Accuracy: 0.0987
# Iteration: 1680, Accuracy: 0.0987
# Iteration: 1690, Accuracy: 0.0987
# Iteration: 1700, Accuracy: 0.0987
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5332\1811053662.py in <module>
#      13
#      14 # Increase the number of iterations and adjust the learning rate as needed
# ---> 15 W1, b1, W2, b2 = gradient_descent(X_train, Y_train, 10000, 0.01)
#
# ~\AppData\Local\Temp\ipykernel_5332\1811053662.py in gradient_descent(X, Y, iterations, alpha)
#       2     W1, b1, W2, b2 = init_params()
#       3     for i in range(iterations):
# ----> 4         Z1, A1, Z2, A2 = forward_prop(W1, b1, W2, b2, X)
#       5         dW1, db1, dW2, db2 = back_prop(Z1, A1, Z2, A2, W2, X, Y)
#       6         W1, b1, W2, b2 = update_params(W1, b1, W2, b2, dW1, db1, dW2, db2, alpha)
#
# ~\AppData\Local\Temp\ipykernel_5332\319222960.py in forward_prop(W1, b1, W2, b2, X)
#      16     A1 = ReLU(Z1)
#      17     Z2 = W2.dot(A1) + b2
# ---> 18     A2 = stable_softmax(Z2)
#      19     return Z1, A1, Z2, A2
#
# ~\AppData\Local\Temp\ipykernel_5332\319222960.py in stable_softmax(Z)
#       9 def stable_softmax(Z):
#      10     Z -= np.max(Z)  # Subtract the maximum value for stability
# ---> 11     exp_Z = np.exp(Z)
#      12     return exp_Z / np.sum(exp_Z)
#      13
#
# KeyboardInterrupt:
