# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

from scipy import stats
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Dropout

# %%
path_train = "https://raw.githubusercontent.com/codehaku/Machine_Learning/main/Titanic/train.csv"
path_test = "https://raw.githubusercontent.com/codehaku/Machine_Learning/main/Titanic/test.csv"
dataframe0 = pd.read_csv(path_train)
dataframe1 = pd.read_csv(path_test)

# Set the maximum number of rows and columns to be displayed
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Display the full DataFrame
pd.options.display.width = 1000

#print(dataframe0.head(100))

# %%
# Select only the numerical columns in the dataframe0
numerical_columns = dataframe0.select_dtypes(include=[np.number]).columns.tolist()

dataframe0 = dataframe0.drop(['Cabin', 'Name', 'Ticket', 'Embarked'], axis=1)
dataframe0['Sex'] = dataframe0['Sex'].replace(['male','female'],[1,0])

mean_age = dataframe0['Age'].mean()
#print(mean_age)
dataframe0['Age'].fillna(mean_age, inplace=True)
#print(dataframe0.head(100))

# Perform one-hot encoding on the Pclass column
pclass_encoded = pd.get_dummies(dataframe0['Pclass'], prefix='class')
dataframe0 = pd.concat([dataframe0, pclass_encoded], axis=1)
dataframe0 = dataframe0.drop(['Pclass'], axis=1)
#print(dataframe0.head(100))

# Perform binary encoding on the SibSp and Parch columns
dataframe0['SibSp_binary'] = dataframe0['SibSp'].apply(lambda x: 1 if x > 0 else 0)
dataframe0['Parch_binary'] = dataframe0['Parch'].apply(lambda x: 1 if x > 0 else 0)
dataframe0 = dataframe0.drop(['SibSp', 'Parch'], axis=1)
#print(dataframe0.head(10))

# %%
# split training and testing data

train_data = dataframe0.sample(frac=0.8, random_state=0)
test_data = dataframe0.drop(train_data.index)

# training i/p o/p and testing i/p o/p

train_input = train_data[['Sex', 'Age', 'Fare', 'class_1','class_2', 'class_3', 'SibSp_binary', 'Parch_binary']]
train_output = train_data[['Survived']]

test_input = test_data[['Sex', 'Age', 'Fare', 'class_1','class_2', 'class_3', 'SibSp_binary', 'Parch_binary']]
test_output = test_data[['Survived']]

# Define the model architecture
model = Sequential()
model.add(Dense(16, input_shape=(8,), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(8, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy']) # binary_crossentropy
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model.fit(train_input, train_output, validation_split=0.2, epochs=100, batch_size=32, callbacks=[early_stopping])

test_loss_train = model.evaluate(train_input, train_output)
print("Test Loss Train:", test_loss_train)

test_loss_test = model.evaluate(test_input, test_output)
print("Test Loss Test:", test_loss_test)
# Out:
# Epoch 1/100
# 18/18 [==============================] - 4s 46ms/step - loss: 1.8306 - accuracy: 0.5789 - val_loss: 0.9819 - val_accuracy: 0.6364
# Epoch 2/100
# 18/18 [==============================] - 0s 9ms/step - loss: 1.3740 - accuracy: 0.5456 - val_loss: 0.6724 - val_accuracy: 0.6084
# Epoch 3/100
# 18/18 [==============================] - 0s 10ms/step - loss: 1.1163 - accuracy: 0.5772 - val_loss: 0.7301 - val_accuracy: 0.6084
# Epoch 4/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.9384 - accuracy: 0.5965 - val_loss: 0.7123 - val_accuracy: 0.6783
# Epoch 5/100
# 18/18 [==============================] - 0s 10ms/step - loss: 1.2280 - accuracy: 0.5737 - val_loss: 0.6963 - val_accuracy: 0.6783
# Epoch 6/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.9766 - accuracy: 0.6140 - val_loss: 0.6595 - val_accuracy: 0.6503
# Epoch 7/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.8908 - accuracy: 0.6070 - val_loss: 0.6562 - val_accuracy: 0.6503
# Epoch 8/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.8729 - accuracy: 0.6035 - val_loss: 0.6513 - val_accuracy: 0.6503
# Epoch 9/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.8387 - accuracy: 0.6333 - val_loss: 0.6483 - val_accuracy: 0.6434
# Epoch 10/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.9019 - accuracy: 0.6333 - val_loss: 0.6540 - val_accuracy: 0.6783
# Epoch 11/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.8482 - accuracy: 0.6298 - val_loss: 0.6500 - val_accuracy: 0.6573
# Epoch 12/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7430 - accuracy: 0.6456 - val_loss: 0.6454 - val_accuracy: 0.6503
# Epoch 13/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.8024 - accuracy: 0.6526 - val_loss: 0.6375 - val_accuracy: 0.6643
# Epoch 14/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.7418 - accuracy: 0.6596 - val_loss: 0.6334 - val_accuracy: 0.6783
# Epoch 15/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7540 - accuracy: 0.5842 - val_loss: 0.6377 - val_accuracy: 0.6503
# Epoch 16/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7260 - accuracy: 0.6491 - val_loss: 0.6332 - val_accuracy: 0.6503
# Epoch 17/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6857 - accuracy: 0.6649 - val_loss: 0.6279 - val_accuracy: 0.6783
# Epoch 18/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7091 - accuracy: 0.6544 - val_loss: 0.6229 - val_accuracy: 0.6643
# Epoch 19/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7185 - accuracy: 0.6526 - val_loss: 0.6218 - val_accuracy: 0.6643
# Epoch 20/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7010 - accuracy: 0.6526 - val_loss: 0.6188 - val_accuracy: 0.6573
# Epoch 21/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.7215 - accuracy: 0.6561 - val_loss: 0.6184 - val_accuracy: 0.6643
# Epoch 22/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6901 - accuracy: 0.6509 - val_loss: 0.6127 - val_accuracy: 0.6573
# Epoch 23/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6648 - accuracy: 0.6789 - val_loss: 0.6096 - val_accuracy: 0.6643
# Epoch 24/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6516 - accuracy: 0.6719 - val_loss: 0.6121 - val_accuracy: 0.6573
# Epoch 25/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6870 - accuracy: 0.6368 - val_loss: 0.6101 - val_accuracy: 0.6573
# Epoch 26/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6964 - accuracy: 0.6579 - val_loss: 0.6112 - val_accuracy: 0.6573
# Epoch 27/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.6368 - accuracy: 0.6702 - val_loss: 0.6126 - val_accuracy: 0.6573
# Epoch 28/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6304 - accuracy: 0.6561 - val_loss: 0.6117 - val_accuracy: 0.6573
# Epoch 29/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6509 - accuracy: 0.6509 - val_loss: 0.6084 - val_accuracy: 0.6503
# Epoch 30/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6281 - accuracy: 0.6754 - val_loss: 0.6076 - val_accuracy: 0.6503
# Epoch 31/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6121 - accuracy: 0.6561 - val_loss: 0.6061 - val_accuracy: 0.6434
# Epoch 32/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6593 - accuracy: 0.6684 - val_loss: 0.6065 - val_accuracy: 0.6434
# Epoch 33/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6314 - accuracy: 0.6632 - val_loss: 0.6059 - val_accuracy: 0.6434
# Epoch 34/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6517 - accuracy: 0.6474 - val_loss: 0.6047 - val_accuracy: 0.6434
# Epoch 35/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6207 - accuracy: 0.6544 - val_loss: 0.6070 - val_accuracy: 0.6503
# Epoch 36/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6615 - accuracy: 0.6632 - val_loss: 0.6063 - val_accuracy: 0.6503
# Epoch 37/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6173 - accuracy: 0.6614 - val_loss: 0.6046 - val_accuracy: 0.6434
# Epoch 38/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6518 - accuracy: 0.6649 - val_loss: 0.6047 - val_accuracy: 0.6364
# Epoch 39/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6146 - accuracy: 0.6895 - val_loss: 0.6039 - val_accuracy: 0.6573
# Epoch 40/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6376 - accuracy: 0.6842 - val_loss: 0.6035 - val_accuracy: 0.6573
# Epoch 41/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6511 - accuracy: 0.6789 - val_loss: 0.6026 - val_accuracy: 0.6643
# Epoch 42/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6188 - accuracy: 0.6825 - val_loss: 0.6014 - val_accuracy: 0.6783
# Epoch 43/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6327 - accuracy: 0.6860 - val_loss: 0.6005 - val_accuracy: 0.6643
# Epoch 44/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6384 - accuracy: 0.6386 - val_loss: 0.6049 - val_accuracy: 0.6713
# Epoch 45/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6165 - accuracy: 0.6596 - val_loss: 0.6039 - val_accuracy: 0.6643
# Epoch 46/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6534 - accuracy: 0.6860 - val_loss: 0.6047 - val_accuracy: 0.6573
# Epoch 47/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6352 - accuracy: 0.6789 - val_loss: 0.6029 - val_accuracy: 0.6573
# Epoch 48/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6097 - accuracy: 0.6439 - val_loss: 0.6018 - val_accuracy: 0.6434
# Epoch 49/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6354 - accuracy: 0.6439 - val_loss: 0.6008 - val_accuracy: 0.6503
# Epoch 50/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6206 - accuracy: 0.6491 - val_loss: 0.6020 - val_accuracy: 0.6503
# Epoch 51/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6139 - accuracy: 0.6596 - val_loss: 0.6026 - val_accuracy: 0.6503
# Epoch 52/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6242 - accuracy: 0.6544 - val_loss: 0.6009 - val_accuracy: 0.6503
# Epoch 53/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6043 - accuracy: 0.6789 - val_loss: 0.5999 - val_accuracy: 0.6503
# Epoch 54/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6229 - accuracy: 0.6351 - val_loss: 0.6000 - val_accuracy: 0.6503
# Epoch 55/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6152 - accuracy: 0.6544 - val_loss: 0.5993 - val_accuracy: 0.6503
# Epoch 56/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6063 - accuracy: 0.6684 - val_loss: 0.5972 - val_accuracy: 0.6503
# Epoch 57/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6280 - accuracy: 0.6526 - val_loss: 0.5962 - val_accuracy: 0.6503
# Epoch 58/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6417 - accuracy: 0.6439 - val_loss: 0.6020 - val_accuracy: 0.6573
# Epoch 59/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6146 - accuracy: 0.6649 - val_loss: 0.6013 - val_accuracy: 0.6573
# Epoch 60/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.6169 - accuracy: 0.6474 - val_loss: 0.5987 - val_accuracy: 0.6503
# Epoch 61/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5932 - accuracy: 0.6842 - val_loss: 0.5994 - val_accuracy: 0.6503
# Epoch 62/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6453 - accuracy: 0.6702 - val_loss: 0.5978 - val_accuracy: 0.6643
# Epoch 63/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6316 - accuracy: 0.6474 - val_loss: 0.5970 - val_accuracy: 0.6643
# Epoch 64/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6155 - accuracy: 0.6789 - val_loss: 0.5993 - val_accuracy: 0.6993
# Epoch 65/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6055 - accuracy: 0.7018 - val_loss: 0.5969 - val_accuracy: 0.6783
# Epoch 66/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5838 - accuracy: 0.6965 - val_loss: 0.5946 - val_accuracy: 0.7133
# Epoch 67/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.5964 - accuracy: 0.6789 - val_loss: 0.5935 - val_accuracy: 0.7133
# Epoch 68/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6145 - accuracy: 0.6632 - val_loss: 0.5945 - val_accuracy: 0.7133
# Epoch 69/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6124 - accuracy: 0.6825 - val_loss: 0.5943 - val_accuracy: 0.7133
# Epoch 70/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.6233 - accuracy: 0.6649 - val_loss: 0.5906 - val_accuracy: 0.7133
# Epoch 71/100
# 18/18 [==============================] - 0s 9ms/step - loss: 0.6019 - accuracy: 0.6825 - val_loss: 0.5930 - val_accuracy: 0.7203
# Epoch 72/100
# 18/18 [==============================] - 0s 14ms/step - loss: 0.5868 - accuracy: 0.6754 - val_loss: 0.5907 - val_accuracy: 0.7133
# Epoch 73/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5875 - accuracy: 0.6807 - val_loss: 0.5872 - val_accuracy: 0.7133
# Epoch 74/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5820 - accuracy: 0.6930 - val_loss: 0.5876 - val_accuracy: 0.7203
# Epoch 75/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5718 - accuracy: 0.7140 - val_loss: 0.5875 - val_accuracy: 0.7133
# Epoch 76/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5821 - accuracy: 0.6860 - val_loss: 0.5892 - val_accuracy: 0.6713
# Epoch 77/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.5915 - accuracy: 0.6649 - val_loss: 0.5882 - val_accuracy: 0.6713
# Epoch 78/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5876 - accuracy: 0.6772 - val_loss: 0.5907 - val_accuracy: 0.6783
# Epoch 79/100
# 18/18 [==============================] - 0s 12ms/step - loss: 0.6085 - accuracy: 0.6807 - val_loss: 0.5905 - val_accuracy: 0.6783
# Epoch 80/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5955 - accuracy: 0.6772 - val_loss: 0.5894 - val_accuracy: 0.6713
# Epoch 81/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5930 - accuracy: 0.6877 - val_loss: 0.5890 - val_accuracy: 0.6923
# Epoch 82/100
# 18/18 [==============================] - 0s 10ms/step - loss: 0.5973 - accuracy: 0.7035 - val_loss: 0.5889 - val_accuracy: 0.6783
# Epoch 83/100
# 18/18 [==============================] - 0s 11ms/step - loss: 0.5933 - accuracy: 0.6789 - val_loss: 0.5872 - val_accuracy: 0.6713
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5563 - accuracy: 0.7041
# Test Loss Train: [0.5562673211097717, 0.7040673494338989]
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5975 - accuracy: 0.6742
# Test Loss Test: [0.5975415706634521, 0.6741573214530945]

# %%
dataframe1 = dataframe1.drop(['Cabin', 'Name', 'Ticket', 'Embarked'], axis=1)
dataframe1['Sex'] = dataframe1['Sex'].replace(['male','female'],[1,0])

mean_fare = dataframe1['Fare'].mean()
dataframe1['Fare'].fillna(mean_fare, inplace=True)

mean_age = dataframe1['Age'].mean()
dataframe1['Age'].fillna(mean_age, inplace=True)

# Perform one-hot encoding on the Pclass column
pclass_encoded = pd.get_dummies(dataframe1['Pclass'], prefix='class')
dataframe1 = pd.concat([dataframe1, pclass_encoded], axis=1)
dataframe1 = dataframe1.drop(['Pclass'], axis=1)
#print(dataframe1.head())

# Perform binary encoding on the SibSp and Parch columns
dataframe1['SibSp_binary'] = dataframe1['SibSp'].apply(lambda x: 1 if x > 0 else 0)
dataframe1['Parch_binary'] = dataframe1['Parch'].apply(lambda x: 1 if x > 0 else 0)
dataframe1 = dataframe1.drop(['SibSp', 'Parch'], axis=1)
#print(dataframe1.head())

# %%
test_ext_data = dataframe1

test_ext_input = test_ext_data[['Sex', 'Age', 'Fare', 'class_1','class_2', 'class_3', 'SibSp_binary', 'Parch_binary']]

# Get predictions for test data
test_predictions = model.predict(test_ext_input)

# Add predictions to the test dataframe
dataframe1['Survival Prediction'] = test_predictions.flatten()

predictions = np.round(model.predict(test_ext_input)).astype(int)

# Display the updated dataframe
#print(dataframe1.head(500))
# Out:
# 14/14 [==============================] - 0s 4ms/step
# 14/14 [==============================] - 0s 4ms/step

# %%
predictions = model.predict(test_ext_input)
predictions = np.round(predictions).astype(int)
dataframe1['Survived'] = predictions
print(dataframe1.head())
# Out:
# 14/14 [==============================] - 0s 4ms/step
#    PassengerId  Sex   Age     Fare  class_1  class_2  class_3  SibSp_binary  Parch_binary  Survival Prediction  Survived
# 0          892    1  34.5   7.8292        0        0        1             0             0             0.134523         0
# 1          893    0  47.0   7.0000        0        0        1             1             0             0.111501         0
# 2          894    1  62.0   9.6875        0        1        0             0             0             0.077788         0
# 3          895    1  27.0   8.6625        0        0        1             0             0             0.188084         0
# 4          896    0  22.0  12.2875        0        0        1             1             1             0.415352         0

# %%
#display(dataframe1[['PassengerId', 'Survived']])

# %%
# create a new DataFrame with only the PassengerId and Survived columns
output_dataframe1 = dataframe1[['PassengerId', 'Survived']]

# save the DataFrame to a CSV file
output_dataframe1.to_csv('output6.csv', index=False)

# %%
import os
print(os.getcwd())
# Out:
# E:\Work\Code\Projects\Jupyter_Notebook\Jupyter_Notebook\Kaggle_Projects\Titanic
